# %% [markdown]
# # Лабораторная работа N1. Подготовка среды для анализа данных

# %% [markdown]
# ## Выполнение работы

# %% [markdown]
# ### 1. Создание учетной записи в GitHub
# 1. Переход на сайт: https://github.com;
# 2. Нажатие кнопки **"Sign up"**;
# 3. Заполнение регистрационной формы:
# - Указание email-адреса;
# - Создание пароля;
# - Выбор имени пользователя;
# - Подтверждение email.
# 4. Настройка профиля (аватар, био и др.).
# ---
# - Ссылка на аккаунт: https://github.com/nabludanya

# %% [markdown]
# ### 2. Выполнение форка репозитория
# 1. Установка GitHub CLI
# - `winget install --id GitHub.cli`;
# 2. Авторизация
# - `gh auth login`;
# 3. Создание форка с клонированием
# - `gh repo fork chebotarevsa/dap-2024 --clone=true`.

# %% [markdown]
# ### 3. Создание учетной записи в Google Colab
# 1. Переход на сайт: https://colab.research.google.com;
# 2. Авторизация через Google-аккаунт;
# 3. Настройка профиля.

# %% [markdown]
# ### 4. Настройка интеграции Google Colab и GitHub
# 1. Открыт Google Colab;
# 2. Нажата кнопка **"Настройки"**;
# 3. Выбрана вкладка **"GitHub"**;
# 4. Нажата кнопка **"Connect to GitHub"**;
# 5. В появившемся окне подтверждена авторизация.

# %% [markdown]
# ### 5. Создание отчета в Google Colab
# Отчет о выполненной работе создан в формате Jupyter Notebook:
# 1. Создан новый блокнот в Google Colab
# 2. Использована Markdown разметка для оформления:
# - Заголовки разных уровней (`#`, `##`, `###`);
# - Списки (нумерованные и маркированные);
# - Форматированный текст (жирный, курсив, цитаты);
# - Ссылки на внешние ресурсы;
# - Блоки кода.
# ---
# Отчет сохранен как `rep.ipynb`

# %% [markdown]
# ### 6. Сохранение отчета в репозиторий
# 1. Скачивание файла rep.ipynb и сохранение в папку репозитория `./les01`
# >`cp "C:\Users\petrov.d\Downloads\rep.ipynb" les01\`
# 2. Добавление в Git
# >`git add les01/rep.ipynb`
# >`git commit -m "Отчет по лабораторной работе N1"`
# >`git push origin main`
# ---
# Файл `rep.ipynb` сохранен по адресу:
# [github.com/nabludanya/dap-2024/blob/main/les01/rep.ipynb](https://github.com/nabludanya/dap-2024/blob/main/les01/rep.ipynb)

# %% [markdown]
# ### 7. Создание Pull Request
# Pull Request создан в оригинальный репозиторий:
# 1. Переход на страницу форка: [github.com/nabludanya/dap-2024](https://github.com/nabludanya/dap-2024)
# 2. Нажата вкладка **"Pull Requests"** -> **"New Pull Request"**
# 3. Настройка Pull Request:
# - **base repository:** `chebotarevsa/dap-2024`
# - **base:** `main`
# - **head repository:** `nabludanya/dap-2024`
# - **compare:** `main`
# 4. Введено название PR:
#    > **Лабораторная работа №1  Группа 12002408 Петров Даниил Витальевич**
# 5. Нажата кнопка **"Create Pull Request"**
# ---
# Ссылка на Pull Request: [Pull Request](https://github.com/chebotarevsa/dap-2024/pull/номер_пул_реквеста)

# %% [markdown]
# ## Ответы на вопросы

# %% [markdown]
# ### 1. Типы ячеек в Jupyter Notebook
# В Jupyter Notebook существует **три основных типа** ячеек:
# | Тип ячейки | Назначение | Пример использования |
# |------------|------------|---------------------|
# | **Code** | Исполняемый код | Написание Python, R, Julia кода |\
# | **Markdown** | Форматированный текст | Описание, пояснения, заголовки, ссылки |
# | **Raw** | Текст без форматирования | Вставка необрабатываемого текста |
#
# - Дополнительно: Heading (устаревший) - ранее использовался для заголовков, теперь заменен Markdown"

# %% [markdown]
# ### 2. Как с помощью Markdown сформировать иерархический список?
# Для создания иерархического (вложенного) списка используются **отступы** (пробелы или табуляция):
# #### Маркированный список:
# ```markdown
# - Уровень 1
#   - Уровень 2 (отступ 2-4 пробела)
#     - Уровень 3
# ```
# ---
# Результат:
# - Уровень 1
#   - Уровень 2 (отступ 2-4 пробела)
#     - Уровень 3
# #### Нумерованный список:
# ```markdown
# 1. Первый уровень
#    1. Второй уровень\n",
#       1. Третий уровень\n",
# ```
# ---
# Результат:
# 1. Первый уровень
#    1. Второй уровень
#       1. Третий уровень

# %% [markdown]
# ### 3. Как с помощью Markdown оформить цитату?
# Для оформления цитаты используется символ `>`:
# ```
# > Это цитата в Markdown.
# ```
# ---
# Результат:
# > Это цитата в Markdown.
# #### Многоуровневая цитата:
# ```
# > Уровень 1
# >> Уровень 2
# >>> Уровень 3
# ```
# ---
# Результат:
# > Уровень 1
# >> Уровень 2
# >>> Уровень 3

# %% [markdown]
# ### 4. Как в текстовую ячейку вставить отформатированный блок кода?
# Для вставки блока кода используются **тройные обратные кавычки** (```) с указанием языка:
# ```markdown
# ```python
# print(\"Hello, World!\")
# for i in range(10):
#     print(i)
# ```
# ---
# Результат:
# ```python
# print(\"Hello, World!\")
# for i in range(10):
#     print(i)
# ```
#
# #### Для встроенного кода (в строке):
# Используйте функцию `print()` для вывода.

# %% [markdown]
# ### 5. Сколько уровней заголовка существует в Markdown?
# В Markdown существует **6 уровней** заголовков (от H1 до H6):
# ```markdown
# # Заголовок 1-го уровня (H1)
# ## Заголовок 2-го уровня (H2)
# ### Заголовок 3-го уровня (H3)
# #### Заголовок 4-го уровня (H4)
# ##### Заголовок 5-го уровня (H5)
# ###### Заголовок 6-го уровня (H6)
# ```
# ---
# Результат:
# # Заголовок 1-го уровня (H1)
# ## Заголовок 2-го уровня (H2)
# ### Заголовок 3-го уровня (H3)
# #### Заголовок 4-го уровня (H4)
# ##### Заголовок 5-го уровня (H5)
# ###### Заголовок 6-го уровня (H6)
# **Важно:**
# - H1 обычно используется один раз - для названия документа;
# - H2-H6 используются для иерархической структуры;
# - В Jupyter Notebook H1 часто используется для названия блокнота.
