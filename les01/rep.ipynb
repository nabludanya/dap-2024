# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# Лабораторная работа N1. Подготовка среды для анализа данных\n",
    "\n",
    "---\n",
    "\n"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "<a id=\"выполнение-работы\"></a>\n",
    "## Выполнение работы"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "### 1. Создание учетной записи в GitHub\n",
    "\n",
    "1. Переход на сайт: https://github.com\n",
    "2. Нажатие кнопки \"Sign up\"\n",
    "3. Заполнение регистрационной формы:\n",
    "   - Указание email-адреса\n",
    "   - Создание пароля\n",
    "   - Выбор имени пользователя\n",
    "   - Подтверждение email\n",
    "4. Настройка профиля (аватар, био и др.)\n",
    "\n",
    "Ссылка на аккаунт: https://github.com/nabludanya"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "### 2. Выполнение форка репозитория chebotarevsa/dap-2024\n",
    "\n",
    "```bash\n",
    "# Установка GitHub CLI\n",
    "winget install --id GitHub.cli\n",
    "\n",
    "# Авторизация\n",
    "gh auth login\n",
    "\n",
    "# Создание форка с клонированием\n",
    "gh repo fork chebotarevsa/dap-2024 --clone=true\n",
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "### 3. Создание учетной записи в Google Colab\n",
    "\n",
    "1. Переход на сайт: https://colab.research.google.com\n",
    "2. Авторизация через Google-аккаунт\n",
    "3. Настройка профиля\n",
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "### 4. Настройка интеграции Google Colab и GitHub\n",
    "\n",
    "1. Открыт Google Colab\n",
    "2. Нажата кнопка \"Настройки\"\n",
    "3. Выбрана вкладка \"GitHub\"\n",
    "4. Нажата кнопка \"Connect to GitHub\"\n",
    "5. В появившемся окне подтверждена авторизация:\n",
    "\n"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "### 5. Создание отчета в Google Colab\n",
    "\n",
    "Отчет о выполненной работе создан в формате Jupyter Notebook:\n",
    "\n",
    "1. Создан новый блокнот в Google Colab\n",
    "2. Использована Markdown разметка для оформления:\n",
    "   - Заголовки разных уровней (`#`, `##`, `###`)\n",
    "   - Списки (нумерованные и маркированные)\n",
    "   - Форматированный текст (жирный, курсив, цитаты)\n",
    "   - Ссылки на внешние ресурсы\n",
    "   - Блоки кода\n",
    "3. Отчет сохранен как `rep.ipynb`\n",
    "\n"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "### 6. Сохранение отчета в репозиторий\n",
    "\n",
    "Отчет сохранен в директорию `./les01` репозитория:\n",
    "\n",
    "# Открытие репозитория\n",
    "cd dap-2024\n",
    "\n",
    "# Создание папки les01 (если отсутствует)\n",
    "mkdir -p les01\n",
    "\n",
    "# Копирование отчета\n",
    "cp /path/to/rep.ipynb les01/\n",
    "\n",
    "# Добавление в Git\n",
    "git add les01/rep.ipynb\n",
    "git commit -m \"Отчет по лабораторной работе N1\"\n",
    "git push origin main\n",
    "```\n",
    "\n",
    "Файл `rep.ipynb` сохранен по адресу:\n",
    "[github.com/nabludanya/dap-2024/blob/main/les01/rep.ipynb](https://github.com/nabludanya/dap-2024/blob/main/les01/rep.ipynb)"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "### 7. Создание Pull Request\n",
    "\n",
    "Pull Request создан в оригинальный репозиторий:\n",
    "\n",
    "1. Переход на страницу форка: [github.com/nabludanya/dap-2024](https://github.com/nabludanya/dap-2024)\n",
    "2. Нажата кнопка \"Contribute\" -> \"Open Pull Request\"\n",
    "3. Настройка Pull Request:\n",
    "   - **base repository:** `chebotarevsa/dap-2024`\n",
    "   - **base:** `main`\n",
    "   - **head repository:** `nabludanya/dap-2024`\n",
    "   - **compare:** `main`\n",
    "4. Введено название PR:\n",
    "   > **\"Лабораторная работа N1  Группа 12002408 Петров Даниил Витальевич\"**\n",
    "5. Добавлено описание выполненных работ\n",
    "6. Нажата кнопка \"Create Pull Request\"\n",
    "\n",
    "Результат: [Ссылка на Pull Request](https://github.com/chebotarevsa/dap-2024/pull/номер_пул_реквеста)"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "<a id=\"ответы-на-вопросы\"></a>\n",
    "## Ответы на вопросы"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "### 1. Типы ячеек в Jupyter Notebook\n",
    "\n",
    "В Jupyter Notebook существует **три основных типа** ячеек:\n",
    "\n",
    "| Тип ячейки | Назначение | Пример использования |\n",
    "|------------|------------|---------------------|\n",
    "| **Code** | Исполняемый код | Написание Python, R, Julia кода |\n",
    "| **Markdown** | Форматированный текст | Описание, пояснения, заголовки, ссылки |\n",
    "| **Raw** | Текст без форматирования | Вставка необрабатываемого текста |\n",
    "\n",
    "Дополнительно:\n",
    "- Heading (устаревший) - ранее использовался для заголовков, теперь заменен Markdown"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "### 2. Как с помощью Markdown сформировать иерархический список?\n",
    "\n",
    "Для создания иерархического (вложенного) списка используются **отступы** (пробелы или табуляция):\n",
    "\n",
    "#### Маркированный список:\n",
    "\n",
    "```markdown\n",
    "- Уровень 1\n",
    "  - Уровень 2 (отступ 2-4 пробела)\n",
    "    - Уровень 3\n",
    "```\n",
    "\n",
    "Результат:\n",
    "\n",
    "- Уровень 1\n",
    "  - Уровень 2 (отступ 2-4 пробела)\n",
    "    - Уровень 3\n",
    "\n",
    "#### Нумерованный список:\n",
    "\n",
    "```markdown\n",
    "1. Первый уровень\n",
    "   1. Второй уровень\n",
    "      1. Третий уровень\n",
    "```\n",
    "\n",
    "Результат:\n",
    "\n",
    "1. Первый уровень\n",
    "   1. Второй уровень\n",
    "      1. Третий уровень"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "### 3. Как с помощью Markdown оформить цитату?\n",
    "\n",
    "Для оформления цитаты используется символ `>`:\n",
    "\n",
    "```markdown\n",
    "> Это цитата в Markdown.\n",
    "```\n",
    "\n",
    "Результат:\n",
    "\n",
    "> Это цитата в Markdown.\n",
    "\n",
    "#### Многоуровневая цитата:\n",
    "\n",
    "```markdown\n",
    "> Уровень 1\n",
    ">> Уровень 2\n",
    ">>> Уровень 3\n",
    "```\n",
    "\n",
    "Результат:\n",
    "\n",
    "> Уровень 1\n",
    ">> Уровень 2\n",
    ">>> Уровень 3"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "### 4. Как в текстовую ячейку вставить отформатированный блок кода?\n",
    "\n",
    "Для вставки блока кода используются **тройные обратные кавычки** (```) с указанием языка:\n",
    "\n",
    "```markdown\n",
    "```python\n",
    "print(\"Hello, World!\")\n",
    "for i in range(10):\n",
    "    print(i)\n",
    "```\n",
    "```\n",
    "\n",
    "Результат:\n",
    "\n",
    "```python\n",
    "print(\"Hello, World!\")\n",
    "for i in range(10):\n",
    "    print(i)\n",
    "```\n",
    "\n",
    "#### Для встроенного кода (в строке):\n",
    "\n",
    "```markdown\n",
    "Используйте функцию `print()` для вывода.\n",
    "```"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "### 5. Сколько уровней заголовка существует в Markdown?\n",
    "\n",
    "В Markdown существует **6 уровней** заголовков (от H1 до H6):\n",
    "\n",
    "```markdown\n",
    "# Заголовок 1-го уровня (H1)\n",
    "## Заголовок 2-го уровня (H2)\n",
    "### Заголовок 3-го уровня (H3)\n",
    "#### Заголовок 4-го уровня (H4)\n",
    "##### Заголовок 5-го уровня (H5)\n",
    "###### Заголовок 6-го уровня (H6)\n",
    "```\n",
    "\n",
    "Важно:\n",
    "- H1 обычно используется один раз - для названия документа\n",
    "- H2-H6 используются для иерархической структуры\n",
    "- В Jupyter Notebook H1 часто используется для названия блокнота"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "### 6. Шаги процесса анализа данных\n",
    "\n",
    "Процесс анализа данных включает следующие основные шаги:\n",
    "\n",
    "1. **Постановка задачи** - определение цели и вопросов для исследования\n",
    "2. **Сбор данных** - получение данных из различных источников\n",
    "3. **Предобработка данных** - очистка, обработка пропусков, преобразование форматов\n",
    "4. **Исследовательский анализ данных (EDA)** - изучение структуры, статистик, визуализация\n",
    "5. **Инженерия признаков** - создание новых признаков на основе существующих\n",
    "6. **Моделирование** - выбор и применение алгоритмов машинного обучения\n",
    "7. **Оценка модели** - проверка качества и интерпретация результатов\n",
    "8. **Деплой** - внедрение модели в продуктивную среду\n",
    "\n",
    "#### Подробно о шаге 4: Исследовательский анализ данных (EDA)\n",
    "\n",
    "EDA является ключевым этапом, который включает:\n",
    "\n",
    "1. **Общий обзор данных:**\n",
    "   - Просмотр первых/последних строк (`head()`, `tail()`)\n",
    "   - Получение общей информации (`info()`)\n",
    "   - Статистическое описание числовых признаков (`describe()`)\n",
    "\n",
    "2. **Обработка пропущенных значений:**\n",
    "   - Выявление пропусков (`isnull().sum()`)\n",
    "   - Принятие решения: удаление или заполнение пропусков\n",
    "\n",
    "3. **Анализ распределений:**\n",
    "   - Построение гистограмм и boxplot-ов\n",
    "   - Проверка на выбросы\n",
    "   - Анализ корреляций между признаками\n",
    "\n",
    "4. **Визуализация:**\n",
    "   - Использование библиотек Matplotlib, Seaborn, Plotly\n",
    "   - Построение парных графиков (pairplot)\n",
    "   - Создание тепловых карт корреляции\n",
    "\n",
    "5. **Формулировка гипотез:**\n",
    "   - На основе визуального анализа\n",
    "   - Проверка предположений с помощью статистических тестов"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "### 7. Типы данных\n",
    "\n",
    "В Python и библиотеках для анализа данных используются следующие основные типы данных:\n",
    "\n",
    "| Категория | Тип | Описание | Пример |\n",
    "|-----------|-----|----------|--------|\n",
    "| **Числовые** | `int` | Целое число | `42` |\n",
    "| | `float` | Число с плавающей точкой | `3.14` |\n",
    "| **Строковые** | `str` | Строка текста | `\"Hello\"` |\n",
    "| **Логические** | `bool` | True/False | `True` |\n",
    "| **Структуры** | `list` | Упорядоченная коллекция | `[1, 2, 3]` |\n",
    "| | `dict` | Пары ключ-значение | `{\"a\": 1}` |\n",
    "| | `tuple` | Неизменяемый кортеж | `(1, 2)` |\n",
    "| **Специальные** | `NoneType` | Отсутствие значения | `None` |\n",
    "| **Библиотечные** | `numpy.ndarray` | Массив NumPy | `np.array([1,2,3])` |\n",
    "| | `pandas.Series` | Одномерный массив pandas | `pd.Series([1,2])` |\n",
    "| | `pandas.DataFrame` | Двумерная таблица | `pd.DataFrame()` |\n",
    "\n",
    "#### Подробно о типе данных `pandas.DataFrame`\n",
    "\n",
    "DataFrame - это основная структура данных в библиотеке Pandas, представляющая собой двумерную таблицу с индексированными строками и именованными столбцами.\n",
    "\n",
    "Характеристики:\n",
    "- Строки и столбцы имеют индексы/метки\n",
    "- Каждый столбец может содержать данные разных типов\n",
    "- Поддерживает операции, аналогичные SQL и Excel\n",
    "- Обеспечивает эффективную обработку больших объемов данных\n",
    "\n",
    "Создание DataFrame:\n",
    "\n",
    "```python\n",
    "import pandas as pd\n",
    "\n",
    "# Из словаря\n",
    "data = {\n",
    "    'Имя': ['Анна', 'Борис', 'Виктор'],\n",
    "    'Возраст': [25, 30, 35],\n",
    "    'Город': ['Москва', 'СПб', 'Казань']\n",
    "}\n",
    "df = pd.DataFrame(data)\n",
    "\n",
    "# Результат:\n",
    "#    Имя  Возраст   Город\n",
    "# 0  Анна       25  Москва\n",
    "# 1  Борис      30  СПб\n",
    "# 2  Виктор     35  Казань\n",
    "```\n",
    "\n",
    "Основные операции:\n",
    "\n",
    "```python\n",
    "df.head()           # Первые 5 строк\n",
    "df.info()           # Информация о типах данных\n",
    "df['Возраст'].mean() # Среднее значение столбца\n",
    "df[df['Возраст'] > 25]  # Фильтрация\n",
    "```"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "### 8. Что такое Jupyter Notebook, для чего используется?\n",
    "\n",
    "Jupyter Notebook - это веб-приложение с открытым исходным кодом, которое позволяет создавать и обмениваться документами, содержащими живой код, уравнения, визуализации и форматированный текст.\n",
    "\n",
    "Основное использование:\n",
    "\n",
    "1. **Анализ данных:**\n",
    "   - Интерактивное исследование данных\n",
    "   - Очистка и предобработка данных\n",
    "   - Визуализация результатов\n",
    "\n",
    "2. **Машинное обучение:**\n",
    "   - Разработка и экспериментирование с моделями\n",
    "   - Документирование процесса обучения\n",
    "\n",
    "3. **Образование:**\n",
    "   - Создание интерактивных учебных материалов\n",
    "   - Выполнение лабораторных работ\n",
    "   - Демонстрация алгоритмов\n",
    "\n",
    "4. **Научные исследования:**\n",
    "   - Воспроизводимые исследования\n",
    "   - Публикация результатов с кодом\n",
    "\n",
    "5. **Прототипирование:**\n",
    "   - Быстрая проверка идей\n",
    "   - Интерактивная отладка кода\n",
    "\n",
    "Преимущества:\n",
    "- Интерактивность - запуск кода по ячейкам\n",
    "- Визуализация - отображение графиков встроенными средствами\n",
    "- Документирование - Markdown для пояснений\n",
    "- Делимость - легко экспортировать в HTML, PDF, Markdown"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "### 9. Почему Python популярен для анализа данных?\n",
    "\n",
    "Python стал языком N1 для анализа данных по ряду причин:\n",
    "\n",
    "#### 1. Богатая экосистема библиотек\n",
    "\n",
    "| Библиотека | Назначение |\n",
    "|------------|------------|\n",
    "| **NumPy** | Работа с многомерными массивами и математика |\n",
    "| **Pandas** | Манипуляции с табличными данными (DataFrame) |\n",
    "| **Matplotlib/Seaborn** | Визуализация данных |\n",
    "| **Scikit-learn** | Машинное обучение (классика) |\n",
    "| **TensorFlow/PyTorch** | Глубокое обучение |\n",
    "| **Statsmodels** | Статистическое моделирование |\n",
    "| **Plotly/Dash** | Интерактивная визуализация и дашборды |\n",
    "\n",
    "#### 2. Простота и читаемость\n",
    "- Интуитивно понятный синтаксис\n",
    "- Низкий порог входа для новичков\n",
    "- Быстрая разработка (rapid prototyping)\n",
    "\n",
    "#### 3. Кроссплатформенность\n",
    "- Работает на Windows, macOS, Linux\n",
    "- Облачные среды (Google Colab, Kaggle, JupyterHub)\n",
    "\n",
    "#### 4. Сообщество\n",
    "- Огромное количество документации и туториалов\n",
    "- Активная поддержка на Stack Overflow и форумах\n",
    "- Постоянное развитие библиотек\n",
    "\n",
    "#### 5. Интеграция\n",
    "- Легко интегрируется с базами данных (SQL, MongoDB)\n",
    "- Поддерживает REST API, веб-скрапинг\n",
    "- Работа с большими данными (PySpark, Dask)\n",
    "\n",
    "#### 6. Интерактивные среды\n",
    "- Jupyter Notebook и Google Colab\n",
    "- IDE для разработки (PyCharm, VS Code)\n",
    "\n",
    "#### 7. Корпоративное использование\n",
    "- Применяется в Google, Facebook, Netflix, Airbnb\n",
    "- Широкий рынок вакансий для Data Scientist и аналитиков"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "### 10. Обязательно ли использовать Jupyter Notebook для анализа данных?\n",
    "\n",
    "Нет, не обязательно. Jupyter Notebook - это инструмент, а не обязательное требование. Выбор зависит от:\n",
    "\n",
    "#### Когда использовать Jupyter Notebook:\n",
    "\n",
    "- Исследовательский анализ (EDA) - удобно просматривать данные и графики\n",
    "- Обучение и преподавание - интерактивное объяснение концепций\n",
    "- Прототипирование - быстрая проверка идей\n",
    "- Документирование - код и пояснения в одном файле\n",
    "- Научные исследования - воспроизводимость экспериментов\n",
    "\n",
    "#### Альтернативы Jupyter Notebook:\n",
    "\n",
    "| Инструмент | Для чего используется | Преимущества |\n",
    "|------------|----------------------|--------------|\n",
    "| **Python-скрипты (.py)** | Продукционный код | Автоматизация, легкость тестирования |\n",
    "| **IDE (PyCharm, VS Code)** | Разработка проектов | Отладка, рефакторинг, автодополнение |\n",
    "| **Google Colab** | Облачный анализ | Бесплатные GPU, общий доступ |\n",
    "| **JupyterLab** | Расширенная среда | Терминал, множество окон, редактор |\n",
    "| **Deepnote/Kaggle** | Совместная работа | Реальное время, бесплатные ресурсы |\n",
    "| **Quarto/R Markdown** | Научная отчетность | Статическая генерация, множественные форматы |\n",
    "\n",
    "#### Когда НЕ использовать Jupyter:\n",
    "\n",
    "- Крупные проекты - трудно поддерживать миллион строк кода в ноутбуках\n",
    "- Продукционная среда - скрипты и пакеты более производительны\n",
    "- Сложная архитектура - классы и модули лучше организовать в .py\n",
    "- CI/CD пайплайны - автоматизация требует скриптов\n",
    "\n",
    "Вывод: Jupyter Notebook - отличный инструмент для исследований и обучения, но для продукционного кода лучше использовать традиционные Python-скрипты и IDE."
   ]
  }
 ],
 "metadata": {
  "language_info": {
   "name": "python"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 2
}
